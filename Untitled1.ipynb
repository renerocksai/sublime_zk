# %%
import re

# %%
citekey_matcher = re.compile('^@.*{([^,]*)[,]?$')

# %%
bibs = """@misc{MKMyZettelkasten,
  title = {My {{Zettelkasten}}},
  abstract = {I have written many times about Luhmann's Zettelkasten (see Luhmann on "Taking Note" ). I have also written many times on ConnectedText and ...},
  urldate = {2017-10-20},
  url = {http://takingnotenow.blogspot.com/2015/12/my-zettelkasten.html},
  author = {{MK}},file = {/Users/rs/Zotero/storage/A7EKRJX6/MK - My Zettelkasten.html}
}

@misc{WichtigeInformationenzur,
  title = {Wichtige {{Informationen}} Zur Mehrstufigen {{E}}-{{Mail}}-{{Migration}} Zu {{Office}} 365},
  abstract = {Im Rahmen einer Office 365-Bereitstellung k{\"o}nnen Sie die Inhalte von Benutzerpostf{\"a}chern aus einem Quell-E-Mail-System nach Office 365 migrieren. Wenn Sie diesen Vorgang nach und nach ausf{\"u}hren, wird von 'mehrstufiger Migration' gesprochen.},
  urldate = {2017-10-20},
  url = {https://support.office.com/de-de/article/Wichtige-Informationen-zur-mehrstufigen-E-Mail-Migration-zu-Office-365-7e2c82be-5f3d-4e36-bc6b-e5b4d411e207},
  file = {/Users/rs/Zotero/storage/UIJ9Q52S/Wichtige Informationen zur mehrstufigen E-Mail-Mig.html}
}

@misc{UbernahmemigrationOffice365,
  title = {{\"U}bernahmemigration Zu {{Office}} 365},
  abstract = {Durchf{\"u}hren einer {\"U}bernahmemigration von E-Mails zu Office 365},
  urldate = {2017-10-20},
  url = {https://support.office.com/de-de/article/\%C3\%9Cbernahmemigration-zu-Office-365-9496e93c-1e59-41a8-9bb3-6e8df0cd81b4},
  file = {/Users/rs/Zotero/storage/E4D95A7M/Übernahmemigration zu Office 365.html}
}

@misc{Addyourdomain,
  title = {Add Your Domain and Users to {{Office}} 365 Operated by {{21Vianet}}},
  abstract = {This topic applies to Office 365 operated by 21Vianet in China. Step-by-step instructions for adding your domain to Office 365.},
  urldate = {2017-10-20},
  url = {https://support.office.com/en-us/article/Add-your-domain-and-users-to-Office-365-operated-by-21Vianet-1cd4839b-d051-46b8-ab9b-bc7752024e78},
  file = {/Users/rs/Zotero/storage/DKC5VU67/Add your domain and users to Office 365 operated b.html}
}

@misc{Office365Migrationsleistungund,
  title = {Office 365-{{Migrationsleistung}} Und Bew{\"a}hrte {{Methoden}}},
  abstract = {Office 365-Migrationsleistung und bew{\"a}hrte Methoden},
  urldate = {2017-10-20},
  url = {https://support.office.com/de-de/article/Office-365-Migrationsleistung-und-bew\%C3\%A4hrte-Methoden-d9acb371-fd6c-4c14-aa8e-db5cbe39aa57},
  file = {/Users/rs/Zotero/storage/SUDMDB9B/Office 365-Migrationsleistung und bewährte Methode.html}
}

@book{AhrensZettelkastenPrinzipErfolgreichwissenschaftlich2017,
  address = {Norderstedt},
  edition = {1},
  title = {{Das Zettelkasten-Prinzip: Erfolgreich wissenschaftlich Schreiben und Studieren mit effektiven Notizen}},
  isbn = {978-3-7431-2498-1},
  shorttitle = {{Das Zettelkasten-Prinzip}},
  abstract = {Der Schl{\"u}ssel zu erfolgreichem Schreiben und Studieren liegt in der intelligenten Organisation von Notizen. Dieses Buch zeigt Ihnen, wie Sie auf Papier oder digital ihre Gedanken und Fundst{\"u}cke so festhalten, dass Sie 1) mit diesen auch sp{\"a}ter noch etwas anfangen k{\"o}nnen, 2) diese auch wiederfinden, wenn Sie sie brauchen und 3) diese so miteinander kombinieren k{\"o}nnen, dass aus ihnen neue Ideen, gr{\"o}{\ss}ere Gedankenb{\"o}gen und vor allem gute Texte erwachsen. Das Zettelkasten-Prinzip beschreibt die Methode, die es Niklas Luhmann erm{\"o}glichte, zu einem der produktivsten und interessantesten Sozialwissenschaftler des 20. Jahrhunderts zu werden und erl{\"a}utert die lernpsychologischen Hintergr{\"u}nde seiner Funktionsweise.},
  language = {Deutsch},
  publisher = {{Books on Demand}},
  author = {Ahrens, S{\"o}nke},
  month = feb,
  year = {2017}
}

@misc{xkcdPasswordStrength,
  title = {Xkcd: {{Password Strength}}},
  urldate = {2017-10-21},
  url = {https://xkcd.com/936/},
  file = {/Users/rs/Zotero/storage/4DNSQY5B/936.html}
}

@misc{LockerVergissaltenPasswortregeln2017,
  title = {Vergiss Die Alten {{Passwortregeln}}},
  abstract = {Der Verfasser der alten Passwort-Standards bereut seine Fehler. Die neuen Regeln sind gro{\ss}artige Neuigkeiten f{\"u}r alle Internetnutzer.},
  urldate = {2017-10-21},
  url = {https://motherboard.vice.com/de/article/zmmed8/vergiss-die-alten-passwortregeln},
  journal = {Motherboard},
  author = {Locker, Theresa},
  month = aug,
  year = {2017},
  file = {/Users/rs/Zotero/storage/HS3SAFUQ/vergiss-die-alten-passwortregeln.html}
}

@misc{NISTSpecialPublication,
  title = {{{NIST Special Publication}} 800-{{63B}}},
  abstract = {NIST Special Publication 800-63B},
  urldate = {2017-10-21},
  url = {https://pages.nist.gov/800-63-3/sp800-63b.html},
  file = {/Users/rs/Zotero/storage/WDYE5L4S/sp800-63b.html}
}

@misc{OverviewMobileDevice,
  title = {Overview of {{Mobile Device Management}} ({{MDM}}) for {{Office}} 365},
  abstract = {You can manage and secure mobile devices when they're connected to your Office 365 organization by using Mobile Device Management for Office 365.},
  urldate = {2017-10-24},
  url = {https://support.office.com/en-us/article/Overview-of-Mobile-Device-Management-MDM-for-Office-365-faa7d8e5-645d-4d59-839c-c8d4c1869e4a},
  file = {/Users/rs/Zotero/storage/WEJIN7XN/Overview of Mobile Device Management (MDM) for Off.html}
}

@misc{CapabilitiesbuiltinMobile,
  title = {Capabilities of Built-in {{Mobile Device Management}} for {{Office}} 365},
  abstract = {Mobile Device Management for Office 365 can help you secure and manage mobile devices like iPhones, iPads, Androids, and Windows Phones used in your organization. Create mobile device management policies with settings that can help control access to your organization's Office 365 email and documents for supported mobile devices and apps, and let you wipe a device remotely if it's stolen.},
  urldate = {2017-10-24},
  url = {https://support.office.com/en-us/article/Capabilities-of-built-in-Mobile-Device-Management-for-Office-365-a1da44e5-7475-4992-be91-9ccec25905b0},
  file = {/Users/rs/Zotero/storage/6QSTHRD4/Capabilities of built-in Mobile Device Management .html}
}

@misc{LoweProjectmanagementsurefire,
  title = {Project Management: {{A}} Surefire Way to Kill Your Software Product},
  shorttitle = {Project Management},
  abstract = {If you want to kill a tree, saw it into a pile of logs. If you want to kill a product, saw it into a pile of projects.},
  urldate = {2017-10-24},
  url = {https://techbeacon.com/project-management-surefire-way-kill-your-software-product},
  author = {Lowe, Steven A.},
  file = {/Users/rs/Zotero/storage/2ERUQS5M/Lowe - Project management A surefire way to kill your so.html}
}

@misc{Dr.JoffreyMabumaUberProjektmanagementForschung2017,
  title = {{\"U}ber Das {{Projektmanagement}} in Der {{Forschung}}| {{Projektberatung}} \& {{Training}}},
  abstract = {Erfahren Sie hier, was das Besondere an Projektmanagement in der Forschung ist und welcher Projektmanagementansatz f{\"u}r Forschungsprojekte geeignet ist.},
  urldate = {2017-10-24},
  url = {https://teamwille.de/ueber-das-projektmanagement-in-der-forschung/},
  author = {Dr. Joffrey Mabuma},
  month = mar,
  year = {2017},
  file = {/Users/rs/Zotero/storage/B58M66NB/2017 - Über das Projektmanagement in der Forschung Proje.html}
}

@misc{HowManageYour2017,
  title = {How to {{Manage Your Research Project}}},
  abstract = {Scientists need to learn the skills of research project management to handle constraints like science goals, time, risk, resources, and budget.},
  urldate = {2017-10-24},
  url = {https://www.enago.com/academy/dont-let-science-fail-research-project-management/},
  month = may,
  year = {2017},
  file = {/Users/rs/Zotero/storage/92VBFSJS/2017 - How to Manage Your Research Project.html}
}

@misc{CommunicatingSlipBoxes,
  title = {Communicating with {{Slip Boxes}} by {{Niklas Luhmann}}},
  urldate = {2017-10-24},
  url = {http://luhmann.surge.sh/communicating-with-slip-boxes},
  file = {/Users/rs/Zotero/storage/AY8YFTBH/communicating-with-slip-boxes.html}
}

@misc{christianHowuseOutlines,
  title = {How {{I}} Use {{Outlines}} to {{Write Any Text}}},
  abstract = {The Zettelkasten note-taking method has made book writing and writing scientific papers easy for hundreds of years already.},
  urldate = {2017-10-25},
  url = {http://www.zettelkasten.de/posts/how-i-use-outlines-to-write-any-text/},
  journal = {Zettelkasten Method},
  author = {{christian}},
  file = {/Users/rs/Zotero/storage/BRDAR7S7/how-i-use-outlines-to-write-any-text.html}
}

@misc{saschaHowWriteBook,
  title = {How to {{Write}} a {{Book}} \textendash{} {{Without Even Trying}} (so Hard)},
  abstract = {The Zettelkasten note-taking method has made book writing and writing scientific papers easy for hundreds of years already.},
  urldate = {2017-10-25},
  url = {http://www.zettelkasten.de/posts/write-book-without-even-trying-so-hard/},
  journal = {Zettelkasten Method},
  author = {{sascha}},
  file = {/Users/rs/Zotero/storage/WLU36U45/write-book-without-even-trying-so-hard.html}
}

@misc{christianHowProgramYourself,
  title = {How to {{Program Yourself}} for {{Productivity}} and {{Stop Searching}} for the {{Ideal Software}}},
  abstract = {The Zettelkasten note-taking method has made book writing and writing scientific papers easy for hundreds of years already.},
  urldate = {2017-10-25},
  url = {http://www.zettelkasten.de/posts/how-to-program-yourself-productivity/},
  journal = {Zettelkasten Method},
  author = {{christian}},
  file = {/Users/rs/Zotero/storage/SPEI5LM6/how-to-program-yourself-productivity.html}
}

@misc{PortnyProjectManagementScientists2002,
  title = {Project {{Management}} for {{Scientists}}},
  urldate = {2017-10-29},
  url = {http://www.sciencemag.org/careers/2002/07/project-management-scientists},
  journal = {Science | AAAS},
  author = {Portny, Stanley E. and AustinJul. 12, Jim and {2002} and Am, 8:00},
  month = jul,
  year = {2002},
  file = {/Users/rs/Zotero/storage/EIICVEPP/project-management-scientists.html}
}

@article{Projekt2017,
  title = {{Projekt}},
  copyright = {Creative Commons Attribution-ShareAlike License},
  abstract = {Ein Projekt ist ein zielgerichtetes, einmaliges Vorhaben, das aus einem Satz von abgestimmten, gesteuerten T{\"a}tigkeiten mit Anfangs- und Endtermin besteht und durchgef{\"u}hrt wird, um unter Ber{\"u}cksichtigung von Vorgaben bez{\"u}glich Zeit, Ressourcen (zum Beispiel Finanzierung bzw. Kosten, Produktions- und Arbeitsbedingungen, Personal und Betriebsmittel) und Qualit{\"a}t ein Ziel zu erreichen.
Projekt leitet sich ab von lateinisch proiectum, Neutrum zu proiectus ,nach vorn geworfen`, Partizip Perfekt von proicere ,vorw{\"a}rtswerfen` (vgl. Projektil). Bei Projekten wird unter ,nach vorn' eine zeitliche Dimension verstanden (siehe auch Terminplanung). Das deutsche Wort kommt im sp{\"a}teren 17. Jahrhundert in Gebrauch in der Bedeutung ,,Bauvorhaben``.
Zur Durchf{\"u}hrung von Projekten werden h{\"a}ufig Projektteams gebildet, denen Steuerungsaufgaben obliegen. Um dieses Projektmanagement effizient zu gestalten, werden von Beratungsfirmen und Hochschulen spezielle Lehrg{\"a}nge angeboten.
Viele Projektmanagement-Lehren empfehlen, dass die Ziele bzw. Zielvorgaben eines Projektes nach den SMART-Regeln vorab formuliert werden (SMART = Spezifisch, Messbar, Akzeptiert, Realistisch, Terminiert). F{\"u}r Forschungsprojekte gilt dies aber nur bedingt.
Das Projektziel bestimmt das strategische Vorgehen, dies bestimmt die n{\"o}tigen Prozesse/T{\"a}tigkeiten und die hilfreiche Grundstruktur, welche den Umgang mit den Ressourcen bestimmen.},
  language = {de},
  urldate = {2017-10-29},
  url = {https://de.wikipedia.org/w/index.php?title=Projekt\&oldid=170400845},
  journal = {Wikipedia},
  month = oct,
  year = {2017},
  note = {Page Version ID: 170400845},
  file = {/Users/rs/Zotero/storage/DTF8KYTW/index.html}
}

@misc{WhyCommandandControlMindset2017,
  title = {Why {{The Command}}-and-{{Control Mindset Is Killing Your Company}}},
  abstract = {The world has reached a key moment in the history of the way we work. We have entered a business environment in which command-and-control is highly outdated.},
  urldate = {2017-10-29},
  url = {https://corporate-rebels.com/mindset/},
  journal = {Corporate Rebels},
  month = mar,
  year = {2017},
  file = {/Users/rs/Zotero/storage/7QGR35PC/mindset.html}
}

@misc{xAd4dHFESXxGm40IdsHP1Qpng2000,
  title = {1*{{xAd4dHFESXxGm40IdsHP1Q}}.Png (2000\texttimes{}5264)},
  urldate = {2017-10-31},
  url = {https://cdn-images-1.medium.com/max/2000/1*xAd4dHFESXxGm40IdsHP1Q.png},
  file = {/Users/rs/Zotero/storage/VZQWPJRA/1xAd4dHFESXxGm40IdsHP1Q.html}
}

@article{SabourDynamicRoutingCapsules2017,
  archivePrefix = {arXiv},
  eprinttype = {arxiv},
  eprint = {1710.09829},
  primaryClass = {cs},
  title = {Dynamic {{Routing Between Capsules}}},
  abstract = {A capsule is a group of neurons whose activity vector represents the instantiation parameters of a specific type of entity such as an object or object part. We use the length of the activity vector to represent the probability that the entity exists and its orientation to represent the instantiation paramters. Active capsules at one level make predictions, via transformation matrices, for the instantiation parameters of higher-level capsules. When multiple predictions agree, a higher level capsule becomes active. We show that a discrimininatively trained, multi-layer capsule system achieves state-of-the-art performance on MNIST and is considerably better than a convolutional net at recognizing highly overlapping digits. To achieve these results we use an iterative routing-by-agreement mechanism: A lower-level capsule prefers to send its output to higher level capsules whose activity vectors have a big scalar product with the prediction coming from the lower-level capsule.},
  urldate = {2017-10-31},
  url = {http://arxiv.org/abs/1710.09829},
  journal = {arXiv:1710.09829 [cs]},
  author = {Sabour, Sara and Frosst, Nicholas and Hinton, Geoffrey E.},
  month = oct,
  year = {2017},
  keywords = {Computer Science - Computer Vision and Pattern Recognition},
  file = {/Users/rs/Zotero/storage/U2VWN8QP/Sabour et al. - 2017 - Dynamic Routing Between Capsules.pdf;/Users/rs/Zotero/storage/CSUYVSUL/1710.html}
}

@article{Scientificmanagement2017,
  title = {Scientific Management},
  copyright = {Creative Commons Attribution-ShareAlike License},
  abstract = {Scientific management is a theory of management that analyzes and synthesizes workflows. Its main objective is improving economic efficiency, especially labor productivity. It was one of the earliest attempts to apply science to the engineering of processes and to management. Scientific management is sometimes known as Taylorism after its founder, Frederick Winslow Taylor.
Taylor began the theory's development in the United States during the 1880s and '90s within manufacturing industries, especially steel. Its peak of influence came in the 1910s; In 1913 Vladimir Lenin wrote that the "most widely discussed topic today in Europe, and to some extent in Russia, is the 'system' of the American engineer, Frederick Taylor"; Lenin decried it initially as a "'scientific' system of sweating" more work from laborers. Taylor died in 1915 and by the 1920s, scientific management was still influential but had entered into competition and syncretism with opposing or complementary ideas.
Although scientific management as a distinct theory or school of thought was obsolete by the 1930s, most of its themes are still important parts of industrial engineering and management today. These include analysis; synthesis; logic; rationality; empiricism; work ethic; efficiency and elimination of waste; standardization of best practices; disdain for tradition preserved merely for its own sake or to protect the social status of particular workers with particular skill sets; the transformation of craft production into mass production; and knowledge transfer between workers and from workers into tools, processes, and documentation.},
  language = {en},
  urldate = {2017-10-31},
  url = {https://en.wikipedia.org/w/index.php?title=Scientific_management\&oldid=807906195},
  journal = {Wikipedia},
  month = oct,
  year = {2017},
  note = {Page Version ID: 807906195},
  file = {/Users/rs/Zotero/storage/M5T3G5HK/index.html}
}

@misc{HeusserWhyyourexecs,
  title = {Why Your Execs Don't Get Agile and What You Can Do about It},
  abstract = {Most execs know a little about agile dev methods\textemdash{}but it's not enough. Here are the common misunderstandings and what you can do about them.},
  urldate = {2017-10-31},
  url = {https://techbeacon.com/why-your-execs-dont-get-agile-what-you-can-do-about-it},
  journal = {TechBeacon},
  author = {Heusser, Matthew},
  file = {/Users/rs/Zotero/storage/FEVVQH3A/why-your-execs-dont-get-agile-what-you-can-do-about-it.html}
}

@article{Kanbandevelopment2017,
  title = {Kanban},
  copyright = {Creative Commons Attribution-ShareAlike License},
  abstract = {Kanban is a method for visualizing the flow of work, in order to balance demand with available capacity and spot bottlenecks. Work items are visualized to give participants a view of progress and process, from start to finish. Team members pull work as capacity permits, rather than work being pushed into the process when requested.
In knowledge work and software development, this provides a visual process management system which aids decision-making about what, when and how much to produce. Although the underlying Kanban method originated in lean manufacturing (inspired by the Toyota Production System) it is used in many software development and technical support frameworks, and may be applied to any type of service.},
  language = {en},
  urldate = {2017-10-31},
  url = {https://en.wikipedia.org/w/index.php?title=Kanban_(development)\&oldid=807664390},
  journal = {Wikipedia},
  month = oct,
  year = {2017},
  note = {Page Version ID: 807664390},
  file = {/Users/rs/Zotero/storage/CPUP6PNL/index.html}
}

@book{PinkDriveSurprisingTruth2011,
  address = {New York},
  edition = {Reprint},
  title = {{Drive: The Surprising Truth About What Motivates Us}},
  isbn = {978-1-59448-480-3},
  shorttitle = {{Drive}},
  abstract = {Look out for Daniel Pink's new book, When: The Scientific Secrets of Perfect TimingThe New York Times bestseller that gives readers a paradigm\textemdash{}shattering new way to think about motivation. Most people believe that the best way to motivate is with rewards like money\textemdash{}the carrot-and-stick approach. That's a mistake, says Daniel H. Pink (author of To Sell Is Human: The Surprising Truth About Motivating Others). In this provocative and persuasive new book, he asserts that the secret to high performance and satisfaction-at work, at school, and at home\textemdash{}is the deeply human need to direct our own lives, to learn and create new things, and to do better by ourselves and our world. Drawing on four decades of scientific research on human motivation, Pink exposes the mismatch between what science knows and what business does\textemdash{}and how that affects every aspect of life. He examines the three elements of true motivation\textemdash{}autonomy, mastery, and purpose-and offers smart and surprising techniques for putting these into action in a unique book that will change how we think and transform how we live.},
  language = {Englisch},
  publisher = {{Riverhead Books}},
  author = {Pink, Daniel H.},
  month = apr,
  year = {2011}
}

@article{Bureaucracy2017,
  title = {Bureaucracy},
  copyright = {Creative Commons Attribution-ShareAlike License},
  abstract = {Bureaucracy () refers to both a body of non-elective government officials and an administrative policy-making group. Historically, a bureaucracy was a government administration managed by departments staffed with non-elected officials. Today, bureaucracy is the administrative system governing any large institution. The public administration in many countries is an example of a bureaucracy.
Since being coined, the word bureaucracy has developed negative connotations. Bureaucracies have been criticized as being inefficient, convoluted, or too inflexible to individuals. The dehumanizing effects of excessive bureaucracy became a major theme in the work of German-language writer Franz Kafka and are central to his novels The Trial and The Castle. The elimination of unnecessary bureaucracy is a key concept in modern managerial theory and has been an issue in some political campaigns.
Others have noted the necessity of bureaucracies in modern life. The German sociologist Max Weber argued that bureaucracy constitutes the most efficient and rational way in which one can organize the human activity and that systematic processes and organized hierarchies are necessary to maintain order, maximize efficiency, and eliminate favoritism. On the other hand, Weber also saw unfettered bureaucracy as a threat to individual freedom, trapping individuals in an impersonal "iron cage" of rule-based, rational control.},
  language = {en},
  urldate = {2017-11-01},
  url = {https://en.wikipedia.org/w/index.php?title=Bureaucracy\&oldid=806945650},
  journal = {Wikipedia},
  month = oct,
  year = {2017},
  note = {Page Version ID: 806945650},
  file = {/Users/rs/Zotero/storage/K8MWI9AI/index.html}
}

@article{Coderefactoring2017,
  title = {Code Refactoring},
  copyright = {Creative Commons Attribution-ShareAlike License},
  abstract = {Code refactoring is the process of restructuring existing computer code\textemdash{}changing the factoring\textemdash{}without changing its external behavior. Refactoring improves nonfunctional attributes of the software. Advantages include improved code readability and reduced complexity; these can improve source-code maintainability and create a more expressive internal architecture or object model to improve extensibility. Typically, refactoring applies a series of standardised basic micro-refactorings, each of which is (usually) a tiny change in a computer program's source code that either preserves the behaviour of the software, or at least does not modify its conformance to functional requirements. Many development environments provide automated support for performing the mechanical aspects of these basic refactorings. If done extremely well, code refactoring may also resolve hidden, dormant, or undiscovered bugs or vulnerabilities in the system by simplifying the underlying logic and eliminating unnecessary levels of complexity. If done poorly it may fail the requirement that external functionality not be changed, introduce new bugs, or both.

By continuously improving the design of code, we make it easier and easier to work with. This is in sharp contrast to what typically happens: little refactoring and a great deal of attention paid to expediently adding new features. If you get into the hygienic habit of refactoring continuously, you'll find that it is easier to extend and maintain code.},
  language = {en},
  urldate = {2017-11-01},
  url = {https://en.wikipedia.org/w/index.php?title=Code_refactoring\&oldid=807498440},
  journal = {Wikipedia},
  month = oct,
  year = {2017},
  note = {Page Version ID: 807498440},
  file = {/Users/rs/Zotero/storage/PCLJYTDL/index.html}
}

@misc{PrinciplesAgileManifesto,
  title = {Principles behind the {{Agile Manifesto}}},
  urldate = {2017-11-01},
  url = {http://agilemanifesto.org/principles.html},
  file = {/Users/rs/Zotero/storage/LSRAWUDH/principles.html}
}

@misc{WhatSprintRetrospective,
  title = {What Is a {{Sprint Retrospective}}?},
  abstract = {Learn About the Sprint Retrospective~Event

As described in the Scrum Guide, the Sprint Retrospective is an opportunity for the Scrum Team to inspect itself and create a plan for improvements to be enacted during the next Sprint.},
  urldate = {2017-11-01},
  url = {http://www.scrum.org/resources/what-is-a-sprint-retrospective},
  journal = {Scrum.org},
  file = {/Users/rs/Zotero/storage/NWK2TNKH/what-is-a-sprint-retrospective.html}
}

@article{SchmidtAusArchiv2013,
  title = {Aus Dem {{Archiv}}},
  abstract = {Der Nachlass Niklas Luhmanns \textendash{} eine erste Sichtung:

  copyright = {Creative Commons Attribution-ShareAlike License},
  abstract = {Scrum is a framework for managing software development. It is designed for teams of three to nine developers who break their work into actions that can be completed within fixed duration cycles (called "sprints"), track progress and re-plan in daily 15-minute stand-up meetings, and collaborate to deliver workable software every sprint. Approaches to coordinating the work of multiple scrum teams in larger organizations include Large-Scale Scrum, Scaled Agile Framework (SAFe) and Scrum of Scrums, among others.},
  language = {en},
  urldate = {2017-11-19},
  url = {https://en.wikipedia.org/w/index.php?title=Scrum_(software_development)\&oldid=809007440},
  journal = {Wikipedia},
  month = nov,
  year = {2017},
  note = {Page Version ID: 809007440},
  file = {/Users/rs/Zotero/storage/39WIX5LN/index.html}
}

@misc{BrechnerKanbanAgileProject,
  title = {Kanban: {{Agile Project Management}} with {{Kanban}}: {{Eric Brechner Presentation}} - {{YouTube}}},
  urldate = {2017-11-19},
  url = {https://www.youtube.com/watch?v=CKWvmiY7f_g},
  author = {Brechner, Eric},
  file = {/Users/rs/Zotero/storage/79FWDUGR/watch.html}
}

@misc{ImportanceTimeboxingIterations2013,
  title = {The {{Importance}} of {{Timeboxing}} and {{Iterations}} for {{Agile Planning}}},
  abstract = {(In this blog post we share the first two of the areas that we address in our new  free ebook called Ultimate Agile Planning Handbook)  Timebox \textendash{} Everything  Ti},
  urldate = {2017-11-19},
  url = {https://www.telerik.com/blogs/the-importance-of-timeboxing-and-iterations-for-agile-planning},
  journal = {Telerik Blogs},
  month = sep,
  year = {2013}
}

@article{Agilesoftwaredevelopment2017,
  title = {Agile Software Development},
  copyright = {Creative Commons Attribution-ShareAlike License},
  abstract = {Agile software development describes a set of values and principles for software development under which requirements and solutions evolve through the collaborative effort of self-organizing cross-functional teams. It advocates adaptive planning, evolutionary development, early delivery, and continuous improvement, and it encourages rapid and flexible response to change. These principles support the definition and continuing evolution of many software development methods.
The term agile (sometimes written Agile) was popularized by the Manifesto for agile software development, which defines those values and principles. Agile software development frameworks continue to evolve, two of the most widely used being Scrum and Kanban.},
  language = {en},
  urldate = {2017-11-19},
  url = {https://en.wikipedia.org/w/index.php?title=Agile_software_development\&oldid=810709468},
  journal = {Wikipedia},
  month = nov,
  year = {2017},
  note = {Page Version ID: 810709468},
  file = {/Users/rs/Zotero/storage/8VAJ4C8P/index.html}
}

@misc{ScientificMethod,
  title = {The {{Scientific Method}}},
  urldate = {2017-11-20},
  url = {http://generalhorticulture.tamu.edu/LearningCommunity/ScientificMethod.htm},
  file = {/Users/rs/Zotero/storage/5LFTB83D/ScientificMethod.html}
}

@misc{IntroductionScientificMethod,
  title = {Introduction to the {{Scientific Method}}},
  urldate = {2017-11-20},
  url = {http://teacher.nsrl.rochester.edu/phy_labs/AppendixE/AppendixE.html},
  file = {/Users/rs/Zotero/storage/D74QUHSC/AppendixE.html}
}



"""

# %%
citekey_matcher.findall(bibs)
# Out:
# []
